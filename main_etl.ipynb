# %%
# INSTALL PACKAGES
# %conda install psycopg2-binary
# %conda install psycopg2
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - psycopg2-binary
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.7.5   |       h06a4308_1         113 KB
#     certifi-2021.5.30          |   py37h06a4308_0         139 KB
#     conda-4.10.3               |   py37h06a4308_0         2.9 MB
#     libpq-12.3                 |       h255efa7_3         2.6 MB  conda-forge
#     psycopg2-2.8.6             |   py37h3c74f83_1         159 KB
#     psycopg2-binary-2.8.6      |     pyhd8ed1ab_3           7 KB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
import requests
import os
import json
from TweetCollector_FullArchiveAPI import TweetStreamer
from config import *
from utilities import *

# tweetStreamer object
tweetStreamer = TweetStreamer(BEARER_TOKEN, DATABASE_URI_RDS_TWEETS)

# set query parameters
start_time = "2021-04-08T00:00:00Z"
end_time = "2021-04-09T00:00:00Z"

NOCOUNTRY_LIST = build_country_codes('country_codes_top54.txt')

query_placecountry = '-is:retweet lang:en place_country:GB'
query_hasgeo_neg_uk = '-is:retweet has:geo lang:en -verdict' + NOCOUNTRY_LIST
query_hasgeo_pos_uk = '-is:retweet has:geo lang:en verdict' + NOCOUNTRY_LIST

# GET tweets with tweetStreamer
# It also handles data loading to DB via its tweetLoader
# set recreate_db = True if ran for the first time or need to recreate schema
# specify maximum number of tweets to return
tweetStreamer.get_tweets(start_time, end_time, query_hasgeo_neg_uk, recreate_db=False, max_tweets=500)
# Out:
# HTTP Response:  200
# PAGE:  1
# JSON response meta:
#  {'newest_id': '1380309472971788289', 'oldest_id': '1380307485593067523', 'result_count': 495, 'next_token': 'b26v89c19zqg8o3fostqsbvwrv34t91614cggpipswl8d'}
# HTTP Response:  200
# PAGE:  2
# JSON response meta:
#  {'newest_id': '1380307477930119170', 'oldest_id': '1380303769779412993', 'result_count': 495, 'next_token': 'b26v89c19zqg8o3fostqsbvwlt8gwpfgvo0enrk4qa8hp'}
# HTTP Response:  200
# PAGE:  3
# JSON response meta:
#  {'newest_id': '1380303766943985665', 'oldest_id': '1380300463975849988', 'result_count': 492, 'next_token': 'b26v89c19zqg8o3fostqsbvwh8q6spqbvi8l1x2ee4bct'}
# HTTP Response:  200
# PAGE:  4
# JSON response meta:
#  {'newest_id': '1380300460930764801', 'oldest_id': '1380297756707856386', 'result_count': 493, 'next_token': 'b26v89c19zqg8o3fostqs9tvqe4y063z735zh35gj5jst'}
# HTTP Response:  200
# PAGE:  5
# JSON response meta:
# ...
